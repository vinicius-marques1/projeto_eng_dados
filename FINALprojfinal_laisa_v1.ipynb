# %% [markdown]
# <a href="https://colab.research.google.com/github/vinicius-marques1/projeto_eng_dados/blob/main/FINALprojfinal_laisa_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pymongo[srv] #pymongo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import random as random
plt.style.use("ggplot")

# %%
import numpy as np #pymongo
from matplotlib import pyplot as plt
def get_database():
    from pymongo import MongoClient
    import pymongo

    # URL de conexao
    CONNECTION_STRING = (
        "mongodb+srv://jemimafpassos:041092@cluster0.owswo.mongodb.net/myFirstDatabase"
    )

    from pymongo import MongoClient

    client = MongoClient(CONNECTION_STRING)  # Conexão com o cliente
    return client['Projeto_Final_EngdeDados']  # Base de dados

# %%
dbname = get_database() #pymongo 
collection_name = dbname["dados_global_covid"]

# %%
####################LOCATION WORLD#####################################
detalhes_itens3 = collection_name.find({"location": "World"})
dfworld = pd.DataFrame(list(detalhes_itens3))

# %%
dfworld.isnull().sum().sort_values(ascending=False)
# Out:
# human_development_index    0
# life_expectancy            0
# gdp_per_capita             0
# aged_70_older              0
# aged_65_older              0
# median_age                 0
# population                 0
# people_fully_vaccinated    0
# people_vaccinated          0
# new_deaths                 0
# total_deaths               0
# new_cases                  0
# total_cases                0
# date                       0
# location                   0
# _id                        0
# dtype: int64

# %%
display(dfworld)
# Out:
#                           _id  ... human_development_index
# 0    6140aa1bb5f25a160a5c2865  ...                   0.737
# 1    6140aa1bb5f25a160a5c286d  ...                   0.737
# 2    6140aa1bb5f25a160a5c2887  ...                   0.737
# 3    6140aa1bb5f25a160a5c2896  ...                   0.737
# 4    6140aa1bb5f25a160a5c28a1  ...                   0.737
# ..                        ...  ...                     ...
# 138  6140aa1bb5f25a160a5c2894  ...                   0.737
# 139  6140aa1bb5f25a160a5c2897  ...                   0.737
# 140  6140aa1bb5f25a160a5c28ba  ...                   0.737
# 141  6140aa1bb5f25a160a5c28c3  ...                   0.737
# 142  6140aa1bb5f25a160a5c28ce  ...                   0.737
#
# [143 rows x 16 columns]

# %%
dfworld1 = dfworld[['date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'people_vaccinated', 'people_fully_vaccinated', 'population']]
display(dfworld1)
# Out:
#            date  total_cases  ...  people_fully_vaccinated  population
# 0    2021-02-01    103474137  ...                 11762439  7794798729
# 1    2021-02-09    106970539  ...                 19598915  7794798729
# 2    2021-03-07    116915987  ...                 67069445  7794798729
# 3    2021-03-22    123692736  ...                105145201  7794798729
# 4    2021-04-02    130243222  ...                139716604  7794798729
# ..          ...          ...  ...                      ...         ...
# 138  2021-03-20    122852600  ...                100790859  7794798729
# 139  2021-03-23    124206981  ...                107754731  7794798729
# 140  2021-04-27    148716872  ...                250644583  7794798729
# 141  2021-05-06    156070729  ...                301138135  7794798729
# 142  2021-05-17    163609626  ...                361298915  7794798729
#
# [143 rows x 8 columns]

# %%
from datetime import datetime
dfworld1['date'] = pd.to_datetime(dfworld1['date'], format='%Y-%m-%d')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
display(dfworld1)
dfworld1.dtypes
# Out:
#           date  total_cases  ...  people_fully_vaccinated  population
# 0   2021-02-01    103474137  ...                 11762439  7794798729
# 1   2021-02-09    106970539  ...                 19598915  7794798729
# 2   2021-03-07    116915987  ...                 67069445  7794798729
# 3   2021-03-22    123692736  ...                105145201  7794798729
# 4   2021-04-02    130243222  ...                139716604  7794798729
# ..         ...          ...  ...                      ...         ...
# 138 2021-03-20    122852600  ...                100790859  7794798729
# 139 2021-03-23    124206981  ...                107754731  7794798729
# 140 2021-04-27    148716872  ...                250644583  7794798729
# 141 2021-05-06    156070729  ...                301138135  7794798729
# 142 2021-05-17    163609626  ...                361298915  7794798729
#
# [143 rows x 8 columns]
# date                       datetime64[ns]
# total_cases                         int64
# ...

# %%
dfworld1['month'] = dfworld1['date'].dt.month
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
display(dfworld1)
dfworld1.dtypes
# Out:
#           date  total_cases  ...  population  month
# 0   2021-02-01    103474137  ...  7794798729      2
# 1   2021-02-09    106970539  ...  7794798729      2
# 2   2021-03-07    116915987  ...  7794798729      3
# 3   2021-03-22    123692736  ...  7794798729      3
# 4   2021-04-02    130243222  ...  7794798729      4
# ..         ...          ...  ...         ...    ...
# 138 2021-03-20    122852600  ...  7794798729      3
# 139 2021-03-23    124206981  ...  7794798729      3
# 140 2021-04-27    148716872  ...  7794798729      4
# 141 2021-05-06    156070729  ...  7794798729      5
# 142 2021-05-17    163609626  ...  7794798729      5
#
# [143 rows x 9 columns]
# date                       datetime64[ns]
# total_cases                         int64
# new_cases                           int64
# total_deaths                        int64
# new_deaths                          int64
# people_vaccinated                   int64
# people_fully_vaccinated             int64
# ...

# %%
dfworld1.groupby('month')

# %%
display(dfworld1) #new_deaths, new_cases => não acumula. total_cases, total_deaths, people_vaccinated e people_fully_vaccinated => acumula.
# Out:
#           date  total_cases  ...  population  month
# 0   2021-02-01    103474137  ...  7794798729      2
# 1   2021-02-09    106970539  ...  7794798729      2
# 2   2021-03-07    116915987  ...  7794798729      3
# 3   2021-03-22    123692736  ...  7794798729      3
# 4   2021-04-02    130243222  ...  7794798729      4
# ..         ...          ...  ...         ...    ...
# 138 2021-03-20    122852600  ...  7794798729      3
# 139 2021-03-23    124206981  ...  7794798729      3
# 140 2021-04-27    148716872  ...  7794798729      4
# 141 2021-05-06    156070729  ...  7794798729      5
# 142 2021-05-17    163609626  ...  7794798729      5
#
# [143 rows x 9 columns]

# %%
dfworld.tail() #o dfworld1 é o df com a coluna do mês.
# Out:
#                           _id  ... human_development_index
# 138  6140aa1bb5f25a160a5c2894  ...                   0.737
# 139  6140aa1bb5f25a160a5c2897  ...                   0.737
# 140  6140aa1bb5f25a160a5c28ba  ...                   0.737
# 141  6140aa1bb5f25a160a5c28c3  ...                   0.737
# 142  6140aa1bb5f25a160a5c28ce  ...                   0.737
#
# [5 rows x 16 columns]

# %%
# Utilizamos a função groupby passando o nome da coluna que queremos usar para agrupar
x = dfworld1.groupby('month') #o x é o df agrupado por mês

# %%
#A variável x é um objeto como vários outro do pandas (e.g. uma Series ou um DataFrame). 
#Isso significa que temos várias funções e atributos dentro desse objeto que nós podemos usar.
#O método describe vai nos gerar várias informações, como em um DataFrame normal, mas de forma agrupada por #mês

x.describe() #não faz sentido pegar a media de totais de casos.
# Out:
#       total_cases                ... people_fully_vaccinated
#             count          mean  ...                     75%          max
# month                            ...
# 1            30.0  9.440577e+07  ...            5.787769e+06   11081795.0
# 2            28.0  1.090216e+08  ...            3.853835e+07   52558655.0
# 3            31.0  1.211370e+08  ...            1.092030e+08  131913112.0
# 4            30.0  1.397965e+08  ...            2.292895e+08  270069483.0
# 5            24.0  1.603844e+08  ...            3.681854e+08  395315319.0
#
# [5 rows x 48 columns]

# %%
#Exibo a média de casos, novos casos, novas mortes, total de mortes, pessoas vacinadas e pessoas totalmente vacinadas para cada mês 
x.mean() #faz sentido usar a media para new_cases e new_deaths pq sei que não é cumulativo.
# Out:
#         total_cases      new_cases  ...  people_vaccinated  people_fully_vaccinated
# month                               ...
# 1      9.440577e+07  631158.133333  ...       2.900318e+07             3.498755e+06
# 2      1.090216e+08  398299.357143  ...       1.021303e+08             2.924622e+07
# 3      1.211370e+08  474772.612903  ...       2.415536e+08             9.049213e+07
# 4      1.397965e+08  750059.466667  ...       4.807249e+08             1.962202e+08
# 5      1.603844e+08  678373.416667  ...       6.855864e+08             3.370123e+08
#
# [5 rows x 6 columns]

# %%
#Acessar uma coluna especifica do dfworld1
dfjan = dfworld1[dfworld1['month'] == 1]
#display(dfjan)
dffev = dfworld1[dfworld1['month'] == 2]
dfmar = dfworld1[dfworld1['month'] == 3]
dfabril = dfworld1[dfworld1['month'] == 4]
dfmaio = dfworld1[dfworld1['month'] == 5]
#display(dfmaio)

# %%
x.agg([np.mean]) #um jeito de exibir de maneira mais informativa
# Out:
#         total_cases      new_cases  ... people_vaccinated people_fully_vaccinated
#                mean           mean  ...              mean                    mean
# month                               ...
# 1      9.440577e+07  631158.133333  ...      2.900318e+07            3.498755e+06
# 2      1.090216e+08  398299.357143  ...      1.021303e+08            2.924622e+07
# 3      1.211370e+08  474772.612903  ...      2.415536e+08            9.049213e+07
# 4      1.397965e+08  750059.466667  ...      4.807249e+08            1.962202e+08
# 5      1.603844e+08  678373.416667  ...      6.855864e+08            3.370123e+08
#
# [5 rows x 6 columns]

# %%
# # crio uma variavel em que mostra cada valor de new deaths do dataset
value_newdeaths = (dfworld1["new_deaths"]).values 
print(value_newdeaths)
# Out:
# [10218 15537  5274  7496 10259 10509 13295 11172 13622 15166  6362 10918
#  13213 12837  9953 12775 12785 15111 16789 16571 13474 12222  7963 14654
#   8575 14360 11086 13738 13139 14940 17308  6894  6949 12277 11875 13342
#   9902 13937  7341 11370 10165 11339  6480 13745 15729 10769 15371 13248
#  17906 16021  7990 11073 10017  7832 10574 11827 14848 12415  9552  9805
#   8512  5801  7474 12574 11650  8348  8664 17051 10137 10250  8140  9691
#   9628  8397 14278 10091 11346 12534  7986 13403 12473 11048  5434 14118
#   8968 10768 11339  7986 10399  9837 12023 15003 13177 13344 12776 15728
#   6860  9981  9890 10125 14205 10149 16583 13294  5880 11180  9767 11573
#   8625 14249  8824  8433 10324 16680 14947  8332  9722 13422  9308 13551
#  14201  9673 16706  9426 14836 12003 10434  6821  6930 13905 13130 17104
#  15335 15053 13586  7209  9778  5499  8046 11106 14497 14245 10644]

# %%
#Tentativa de grafico exibindo total de casos, novas mortes, total de obitos e pessoas totalmente vacinadas por mês - globalmente
vacinacaoglobal= dfworld1[['date', 'total_cases', 'people_vaccinated', 'people_fully_vaccinated']]
vacinacaoglobal2 = (vacinacaoglobal[(vacinacaoglobal['date'] > '2021-05-23') & (vacinacaoglobal['date'] < '2021-05-25')])
vacinacaoglobal3 = vacinacaoglobal2[['total_cases', 'people_vaccinated', 'people_fully_vaccinated']] 
vacinacaoglobal3
vacinacao_values = vacinacaoglobal3.values
vacinacao_values #array([[167316360, 775676935, 395315319]])
a=['total_cases', 'people_vaccinated', 'people_fully_vaccinated']

# %%
# Out:
# ['total_cases', 'people_vaccinated', 'people_fully_vaccinated']

# %%
#Tentativa de grafico de quantidade de óbitos globais por covid-19  por mês
plt.style.use("ggplot")
teste_x = (x.mean()["new_deaths"]).values
x1 =  np.arange(len(teste_x))

plt.bar(x1, teste_x, width=0.25, label = 'new-deaths', color = 'thistle')

meses = ['jan','fev','mar','abril','maio']
plt.xlabel('Meses')
plt.ylabel('new_deaths')
plt.xticks([x + 0.25 for x in range(len(teste_x))], meses)
plt.title("Quantidade média de novos óbitos globais por COVID-19 nos primeiros 5 meses de 2021")

plt.show()

# %%
x.mean()
# Out:
#         total_cases      new_cases  ...  people_vaccinated  people_fully_vaccinated
# month                               ...
# 1      9.440577e+07  631158.133333  ...       2.900318e+07             3.498755e+06
# 2      1.090216e+08  398299.357143  ...       1.021303e+08             2.924622e+07
# 3      1.211370e+08  474772.612903  ...       2.415536e+08             9.049213e+07
# 4      1.397965e+08  750059.466667  ...       4.807249e+08             1.962202e+08
# 5      1.603844e+08  678373.416667  ...       6.855864e+08             3.370123e+08
#
# [5 rows x 6 columns]

# %%
x.describe()
# Out:
#       total_cases                ... people_fully_vaccinated
#             count          mean  ...                     75%          max
# month                            ...
# 1            30.0  9.440577e+07  ...            5.787769e+06   11081795.0
# 2            28.0  1.090216e+08  ...            3.853835e+07   52558655.0
# 3            31.0  1.211370e+08  ...            1.092030e+08  131913112.0
# 4            30.0  1.397965e+08  ...            2.292895e+08  270069483.0
# 5            24.0  1.603844e+08  ...            3.681854e+08  395315319.0
#
# [5 rows x 48 columns]

# %%
x.mean().new_deaths
# Out:
# month
# 1    13379.833333
# 2    10624.214286
# 3     9119.354839
# 4    12138.500000
# 5    12193.041667
# Name: new_deaths, dtype: float64

# %%
#location: World
#GRAFICO DE BARRAS DE NOVOS CASOS GLOBAIS.

x.mean()['new_cases'].plot( kind = "bar", color='rosybrown', title='Quantidade média de novos casos globais de COVID-19 nos primeiros 5 meses de 2021', ylabel='new_cases')

# %%
vacinacaoglobal3.people_fully_vaccinated
# Out:
# 110    395315319
# Name: people_fully_vaccinated, dtype: int64

# %%
import seaborn as sns

# %%
####################LOCATION GERAL#####################################
detalhes_itens5 = collection_name.find()
df_all = pd.DataFrame(list(detalhes_itens5))
df_all[['location']] = df_all[['location']].fillna('')
df_all[['new_cases', 'new_deaths', 'population', 'people_vaccinated']] = df_all[['new_cases', 'new_deaths', 'population', 'people_vaccinated']].fillna(0)

# %%
display(df_all)
# Out:
#                             _id  ... people_fully_vaccinated
# 0      6140a9ffb5f25a160a5bb201  ...                     NaN
# 1      6140a9ffb5f25a160a5bb1ee  ...                     NaN
# 2      6140a9ffb5f25a160a5bb1f1  ...                     NaN
# 3      6140a9ffb5f25a160a5bb204  ...                     NaN
# 4      6140a9ffb5f25a160a5bb205  ...                     NaN
# ...                         ...  ...                     ...
# 30864  6140aa1bb5f25a160a5c2a2b  ...                     NaN
# 30865  6140aa1bb5f25a160a5c2a2f  ...                     NaN
# 30866  6140aa1bb5f25a160a5c2a32  ...                     NaN
# 30867  6140aa1bb5f25a160a5c2a42  ...                     NaN
# 30868  6140aa1bb5f25a160a5c2a6a  ...                 85607.0
#
# [30869 rows x 21 columns]

# %%
df_cut= df_all[['people_vaccinated', 'people_fully_vaccinated', 'location', 'continent', 'new_cases', 'total_deaths','new_deaths', 'population']]
#df_cut = df_cut.fillna(0)
display(df_cut)
continent_agrup = df_cut.groupby('continent')
# Out:
#        people_vaccinated  people_fully_vaccinated  ... new_deaths population
# 0                    0.0                      NaN  ...        9.0   38928341
# 1                    0.0                      NaN  ...        0.0   38928341
# 2                    0.0                      NaN  ...        7.0   38928341
# 3                    0.0                      NaN  ...        5.0   38928341
# 4                    0.0                      NaN  ...        7.0   38928341
# ...                  ...                      ...  ...        ...        ...
# 30864            12579.0                      NaN  ...        5.0   14862927
# 30865            25077.0                      NaN  ...        4.0   14862927
# 30866            31325.0                      NaN  ...        1.0   14862927
# 30867            42729.0                      NaN  ...        2.0   14862927
# 30868           414735.0                  85607.0  ...        0.0   14862927
#
# [30869 rows x 8 columns]

# %%
continent_agrup.describe()
# Out:
#               people_vaccinated                ... new_deaths
#                           count          mean  ...        75%     max
# continent                                      ...
# Africa                   7957.0  7.427349e+04  ...        3.0   844.0
# Asia                     6960.0  1.523331e+06  ...       18.0  4529.0
# Europe                   7139.0  1.506149e+06  ...       58.0  1826.0
# North America            4135.0  3.069334e+06  ...        7.0  4475.0
# Oceania                  1608.0  9.352334e+03  ...        0.0    13.0
# South America            1783.0  1.795820e+06  ...      145.0  4249.0
#
# [6 rows x 40 columns]

# %%
continent_agrup.mean()
# Out:
#                people_vaccinated  ...  new_deaths
# continent                         ...
# Africa              7.427349e+04  ...    7.868292
# Asia                1.523331e+06  ...   44.992241
# Europe              1.506149e+06  ...   72.188402
# North America       3.069334e+06  ...   85.819105
# Oceania             9.352334e+03  ...    0.094527
# South America       1.795820e+06  ...  220.020752
#
# [6 rows x 5 columns]

# %%
continent_agrup.mean().new_deaths.plot(kind='pie', autopct='%1.1f%%')
plt.axis('equal')
plt.title("Média de novos óbitos por continente em decorrência da pandemia de COVID-19 nos primeiros 5 meses de 2021", fontsize=12)
plt.show()

# %%
continent_agrup.mean().new_cases.plot(kind='pie', autopct='%1.1f%%')
plt.axis('equal')
plt.title("Média de novos casos de COVID-19 por continente nos primeiros 5 meses de 2021", fontsize=12)
plt.show()

# %%
display(df_cut)
# Out:
#        people_vaccinated  people_fully_vaccinated  ... new_deaths population
# 0                    0.0                      NaN  ...        9.0   38928341
# 1                    0.0                      NaN  ...        0.0   38928341
# 2                    0.0                      NaN  ...        7.0   38928341
# 3                    0.0                      NaN  ...        5.0   38928341
# 4                    0.0                      NaN  ...        7.0   38928341
# ...                  ...                      ...  ...        ...        ...
# 30864            12579.0                      NaN  ...        5.0   14862927
# 30865            25077.0                      NaN  ...        4.0   14862927
# 30866            31325.0                      NaN  ...        1.0   14862927
# 30867            42729.0                      NaN  ...        2.0   14862927
# 30868           414735.0                  85607.0  ...        0.0   14862927
#
# [30869 rows x 8 columns]

# %%
#Entendendo que não tem nenhuma informação sobre os dados de vacinação do continente da Oceania
df_vacina_oceania = (df_all[(df_all['continent'] == 'Oceania')]) 
df_vacina_oceania
# Out:
#                             _id  ... people_fully_vaccinated
# 1509   6140aa00b5f25a160a5bb824  ...                     NaN
# 1510   6140aa00b5f25a160a5bb838  ...                     NaN
# 1511   6140aa00b5f25a160a5bb83d  ...                     NaN
# 1512   6140aa00b5f25a160a5bb850  ...                     NaN
# 1513   6140aa00b5f25a160a5bb851  ...                     NaN
# ...                         ...  ...                     ...
# 30482  6140aa1bb5f25a160a5c2811  ...                     NaN
# 30483  6140aa1bb5f25a160a5c2819  ...                     NaN
# 30484  6140aa1bb5f25a160a5c2820  ...                     NaN
# 30485  6140aa1bb5f25a160a5c2826  ...                     NaN
# 30486  6140aa1bb5f25a160a5c2828  ...                     NaN
#
# [1608 rows x 21 columns]

# %%
###########SOMA##########################
import plotly.express as px
def vacina_sum():
    dff= df_all[df_all['continent']!='NaN']
    dff = (df_all[(df_all['date'] > '2021-05-21') & (df_all['date'] < '2021-05-23')])
    temp = dff.groupby('continent')['people_fully_vaccinated', 'people_vaccinated'].sum().reset_index()
    temp=temp.melt(id_vars='continent',value_vars=['people_fully_vaccinated', 'people_vaccinated'],var_name='Status',value_name='Quantidade de pessoas')
    people_fully_vaccinated = '#21bf82'
    people_vaccinated='#A6636B'
    fig = px.bar(temp, x="continent",#y= 'people_fully_vaccinated',
                    y="Quantidade de pessoas", 
                    color='Status',
                    height=600,
                    title='Status da vacinação contra a COVID-19 por continente nos primeiros 5 meses de 2021',
                    color_discrete_sequence = [people_fully_vaccinated,people_vaccinated])
    fig.update_layout(xaxis_rangeslider_visible=True)
    fig.show()
  
vacina_sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="411651bf-a065-4a46-9ad8-c8a7d5aec7a3" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %%
dff_sum= df_all[df_all['continent']!='NaN']
dff_sum = (df_all[(df_all['date'] > '2021-05-21') & (df_all['date'] < '2021-05-23')])
temp_sum = dff_sum.groupby('continent')['people_fully_vaccinated', 'people_vaccinated'].sum().reset_index()
temp_sum
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#        continent  people_fully_vaccinated  people_vaccinated
# 0         Africa                6209961.0         16196184.0
# 1           Asia               74248008.0        201732289.0
# 2         Europe               90115397.0        183819377.0
# 3  North America              144346058.0        205746345.0
# 4        Oceania                      0.0                0.0
# 5  South America               34372434.0         68993058.0

# %%
dff_sum
# Out:
#                             _id  ... people_fully_vaccinated
# 108    6140a9ffb5f25a160a5bb309  ...               6841841.0
# 345    6140a9ffb5f25a160a5bb398  ...                     NaN
# 386    6140a9ffb5f25a160a5bb27a  ...                     NaN
# 562    6140a9ffb5f25a160a5bb545  ...                     NaN
# 608    6140a9ffb5f25a160a5bb427  ...                     NaN
# ...                         ...  ...                     ...
# 30260  6140aa1bb5f25a160a5c28d3  ...             388837124.0
# 30364  6140aa1bb5f25a160a5c277c  ...                     NaN
# 30674  6140aa1bb5f25a160a5c29f1  ...                  3199.0
# 30844  6140aa1bb5f25a160a5c2a80  ...                273725.0
# 30849  6140aa1bb5f25a160a5c2962  ...                     NaN
#
# [209 rows x 21 columns]
